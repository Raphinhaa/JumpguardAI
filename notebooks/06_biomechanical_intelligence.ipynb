# %% [markdown]
# # Prompt 6 - Biomechanical Intelligence Engine
#
# This notebook creates interpretable, dataset-relative athlete assessments without ACL prediction, probability estimation, or diagnosis.

# %%
from pathlib import Path
import os
import sys

PROJECT_ROOT = Path.cwd()
if not (PROJECT_ROOT / 'src').exists():
    PROJECT_ROOT = PROJECT_ROOT.parent
os.chdir(PROJECT_ROOT)
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from src.biomechanical_intelligence import (
    assess_biomechanics,
    export_intelligence_outputs,
    export_intelligence_plots,
)
from src.eda import load_feature_table

# %%
feature_table = load_feature_table('data/processed/features.csv')
feature_table.shape
# Out:
# (258, 62)

# %%
result = assess_biomechanics(feature_table)
result.athlete_summary.head()
# Out:
#    participant_id  trial_count  empty_trial_count  hip_flexion_right_mean  \
# 0               1            6                  0               31.644380
# 1               2            6                  0               47.305332
# 2               3            6                  0               48.566764
# 3               4            6                  0               60.614318
# 4               6            6                  0               47.549134
#
#    hip_flexion_right_median  hip_flexion_right_std  \
# 0                 29.786170              27.511033
# 1                 58.897635              29.337651
# 2                 63.619625              22.649699
# 3                 72.889523              40.539178
# 4                 67.805250              37.579780
#
#    hip_flexion_right_variance  hip_flexion_right_maximum  \
# 0                  757.466369                  70.546670
# 1                  860.869220                  81.750857
# ...

# %%
result.population_statistics.head(10)
# Out:
#                           feature  count         mean         std         min  \
# 0          hip_flexion_right_mean     42    46.962794   10.219526   28.170436
# 1        hip_flexion_right_median     42    44.824196   17.160896   13.969765
# 2           hip_flexion_right_std     42    31.755881    7.028250   14.072113
# 3      hip_flexion_right_variance     42  1066.574183  435.427940  202.794983
# 4       hip_flexion_right_maximum     42    92.327959   10.998035   70.546670
# 5       hip_flexion_right_minimum     42     4.154237   12.791543  -23.899633
# 6           hip_flexion_right_rom     42    88.173722   18.166902   45.783227
# 7  hip_flexion_right_time_to_peak     42     2.870778    0.656089    1.321333
# 8           hip_flexion_left_mean     42    46.836029    9.838548   26.767739
# 9         hip_flexion_left_median     42    44.746614   16.798865   10.342917
#
#           p05         p25       median          p75          p95          max
# ...

# %%
result.athlete_percentiles.head(10)
# Out:
#    participant_id                         feature       value  percentile  \
# 0               1          hip_flexion_right_mean   31.644380    9.523810
# 1               1        hip_flexion_right_median   29.786170   19.047619
# 2               1           hip_flexion_right_std   27.511033   35.714286
# 3               1      hip_flexion_right_variance  757.466369   35.714286
# 4               1       hip_flexion_right_maximum   70.546670    2.380952
# 5               1       hip_flexion_right_minimum   -1.010491   40.476190
# 6               1           hip_flexion_right_rom   71.557161   28.571429
# 7               1  hip_flexion_right_time_to_peak    2.836000   47.619048
# 8               1           hip_flexion_left_mean   31.266867    7.142857
# 9               1         hip_flexion_left_median   30.289207   21.428571
#
#     z_score  population_mean  population_std  population_p05  population_p95
# 0 -1.498936        46.962794       10.219526       29.609551       65.422519
# ...

# %%
result.observations.head(20)
# Out:
#     participant_id  category                              feature       value  \
# 0                1     ankle              ankle_angle_left_median    0.100038
# 1                1     ankle             ankle_angle_right_median   -0.244342
# 2                1       hip             hip_flexion_left_maximum   69.224326
# 3                1       hip            hip_flexion_right_maximum   70.546670
# 4                2     ankle             ankle_angle_left_maximum   39.541040
# 5                2       hip        hip_flexion_left_time_to_peak    4.125333
# 6                2       hip       hip_flexion_right_time_to_peak    3.927333
# 7                2  symmetry  knee_flexion_rom_percent_difference    0.999327
# 8                3     ankle                ankle_angle_left_mean   19.430080
# 9                3     ankle              ankle_angle_left_median   28.537471
# 10               3     ankle             ankle_angle_left_minimum  -28.015010
# ...

# %%
result.knowledge_mapping.head(15)
# Out:
#                            feature category                       concept  \
# 0           hip_flexion_right_mean      hip  Hip sagittal-plane mechanics
# 1         hip_flexion_right_median      hip  Hip sagittal-plane mechanics
# 2            hip_flexion_right_std      hip  Hip sagittal-plane mechanics
# 3       hip_flexion_right_variance      hip  Hip sagittal-plane mechanics
# 4        hip_flexion_right_maximum      hip  Hip sagittal-plane mechanics
# 5        hip_flexion_right_minimum      hip  Hip sagittal-plane mechanics
# 6            hip_flexion_right_rom      hip  Hip sagittal-plane mechanics
# 7   hip_flexion_right_time_to_peak      hip  Hip sagittal-plane mechanics
# 8            hip_flexion_left_mean      hip  Hip sagittal-plane mechanics
# 9          hip_flexion_left_median      hip  Hip sagittal-plane mechanics
# 10            hip_flexion_left_std      hip  Hip sagittal-plane mechanics
# 11       hip_flexion_left_variance      hip  Hip sagittal-plane mechanics
# ...

# %%
paths = export_intelligence_outputs(result)
plot_paths = export_intelligence_plots(result, participant_id=1)
{name: str(path) for name, path in paths.items()}, [str(path) for path in plot_paths]
# Out:
# ({'athlete_summary': 'reports/athlete_summary.csv',
#   'population_statistics': 'reports/population_statistics.csv',
#   'athlete_percentiles': 'reports/athlete_percentiles.csv',
#   'biomechanical_observations': 'reports/biomechanical_observations.csv',
#   'knowledge_mapping': 'reports/biomechanical_knowledge_mapping.csv'},
#  ['reports/biomechanical_intelligence_plots/athlete_1_radar.png',
#   'reports/biomechanical_intelligence_plots/athlete_1_symmetry.png',
#   'reports/biomechanical_intelligence_plots/athlete_1_percentiles.png',
#   'reports/biomechanical_intelligence_plots/athlete_1_feature_comparison.png',
#   'reports/biomechanical_intelligence_plots/athlete_1_vs_population.png'])
