# %% [markdown]
# # Prompt 8 - Dashboard and Visualization Layer
#
# This notebook demonstrates loading the static dashboard from existing Prompt 3-7 outputs only.

# %%
from pathlib import Path
import os
import sys

PROJECT_ROOT = Path.cwd()
if not (PROJECT_ROOT / 'src').exists():
    PROJECT_ROOT = PROJECT_ROOT.parent
os.chdir(PROJECT_ROOT)
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from src.dashboard import Dashboard

# %%
dashboard = Dashboard()
len(dashboard.athlete_ids), len(dashboard.feature_names)
# Out:
# (43, 57)

# %%
dashboard.show_athlete(1).keys()
# Out:
# dict_keys(['participant_id', 'summary', 'percentiles', 'observations', 'reports', 'missing_feature_count'])

# %%
dashboard.show_feature('knee_flexion_right_rom')
# Out:
# {'feature': 'knee_flexion_right_rom',
#  'population': {'feature': 'knee_flexion_right_rom',
#   'count': 42,
#   'mean': 98.53739797,
#   'std': 9.934970804,
#   'min': 77.39690503,
#   'p05': 84.16702773,
#   'p25': 90.95458739,
#   'median': 98.16515963,
#   'p75': 104.9167317,
#   'p95': 112.6054897,
#   'max': 120.5057415},
#  'athlete_values': [{'participant_id': 1,
#    'feature': 'knee_flexion_right_rom',
#    'value': 85.57483822,
#    'percentile': 9.523809524,
#    'z_score': -1.304740599,
#    'population_mean': 98.53739797,
#    'population_std': 9.934970804,
#    'population_p05': 84.16702773,
#    'population_p95': 112.6054897},
#   {'participant_id': 2,
#    'feature': 'knee_flexion_right_rom',
#    'value': 107.1077668,
#    'percentile': 80.95238095,
#    'z_score': 0.862646606,
#    'population_mean': 98.53739797,
#    'population_std': 9.934970804,
#    'population_p05': 84.16702773,
#    'population_p95': 112.6054897},
#   {'participant_id': 3,
# ...

# %%
dashboard.show_symmetry(participant_id=1)
# Out:
# {'rows': [{'participant_id': 1,
#    'feature': 'ankle_angle_rom_absolute_difference',
#    'value': 2.237167782,
#    'percentile': 47.61904762,
#    'z_score': -0.2079746062,
#    'population_mean': 2.587193817,
#    'population_std': 1.68302295,
#    'population_p05': 0.5933290985,
#    'population_p95': 5.120282477},
#   {'participant_id': 1,
#    'feature': 'ankle_angle_rom_percent_difference',
#    'value': 3.183782202,
#    'percentile': 47.61904762,
#    'z_score': -0.195330179,
#    'population_mean': 3.683862132,
#    'population_std': 2.560177501,
#    'population_p05': 0.7660448634,
#    'population_p95': 7.564692367},
#   {'participant_id': 1,
#    'feature': 'ankle_angle_rom_symmetry_index',
#    'value': 0.6516100961,
#    'percentile': 64.28571429,
#    'z_score': 0.1566575736,
#    'population_mean': -0.01690833512,
#    'population_std': 4.267386606,
#    'population_p05': -5.409418999,
#    'population_p95': 7.525522899},
#   {'participant_id': 1,
# ...

# %%
dashboard.show_time_series(1)
# Out:
# {'available': False,
#  'reason': 'No already-loaded Dataset object was supplied to Dashboard.'}

# %%
html_path = dashboard.launch('reports/dashboard')
html_path
# Out:
# PosixPath('reports/dashboard/index.html')

# %%
dashboard.load_report(1, 'md').splitlines()[:8]
# Out:
# ['# Athlete Report: Participant 1',
#  '',
#  'This report is descriptive and dataset-relative. It does not provide medical diagnosis, treatment advice, injury prediction, or probabilistic injury estimates.',
#  '',
#  '## Athlete Overview',
#  '',
#  '| field | value |',
#  '| --- | --- |']
